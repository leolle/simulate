# %% [markdown]
# ## 1. 计算2013.01.01至今之间的交易日的数量，并打印出来

# %%
import pandas as pd
import numpy as np

# %%
# 导入数据
trading_date = pd.read_csv('/home/weiwu/share/quant_code/tradingDate/tradingDate.csv', index_col=[0],
                           delim_whitespace=True,header=None,date_parser=lambda x: pd.to_datetime(x, format="%Y%m%d"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/weiwu/.virtualenvs/graph/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-dcdb758c61fe> in <module>()
#       1 # 导入数据
#       2 trading_date = pd.read_csv('/home/weiwu/share/quant_code/tradingDate/tradingDate.csv', index_col=[0],
# ...

# %%
trading_date.head()
# Out:
#           0
# 0  20000104
# 1  20000105
# 2  20000106
# 3  20000107
# 4  20000110

# %%
trading_date
# Out:
#              0
# 0     20000104
# 1     20000105
# 2     20000106
# 3     20000107
# 4     20000110
# 5     20000111
# 6     20000112
# 7     20000113
# 8     20000114
# 9     20000117
# 10    20000118
# 11    20000119
# 12    20000120
# 13    20000121
# 14    20000124
# 15    20000125
# 16    20000126
# 17    20000127
# 18    20000128
# 19    20000214
# 20    20000215
# 21    20000216
# 22    20000217
# 23    20000218
# 24    20000221
# 25    20000222
# 26    20000223
# 27    20000224
# 28    20000225
# 29    20000228
# ...        ...
# 4117  20161121
# 4118  20161122
# 4119  20161123
# 4120  20161124
# 4121  20161125
# 4122  20161128
# 4123  20161129
# 4124  20161130
# 4125  20161201
# 4126  20161202
# 4127  20161205
# 4128  20161206
# 4129  20161207
# 4130  20161208
# 4131  20161209
# 4132  20161212
# 4133  20161213
# 4134  20161214
# 4135  20161215
# 4136  20161216
# 4137  20161219
# 4138  20161220
# 4139  20161221
# 4140  20161222
# 4141  20161223
# 4142  20161226
# ...

# %%
trading_date = trading_date.set_index(pd.DatetimeIndex(trading_date.ix[:,0]))
# Out:
# /home/weiwu/.virtualenvs/graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/weiwu/.virtualenvs/graph/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# ...

# %%
pd.to_datetime(trading_date.iloc[:,0]).astype(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/weiwu/.virtualenvs/graph/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5b28b9c9f642> in <module>()
# ----> 1 pd.to_datetime(trading_date.iloc[:,0]).astype(str)
#
# ...
